# %%
from nytimesarticle import articleAPI

# %%
api = articleAPI('e15cea455f73cc47d6d971667e09c31c:19:44644296')

# %%
## Parsing
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encore("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # we don't need the time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects    
        news.append(dic)
    return(news)

# %%
def get_facets(articles):
    ''' 
    Accepts output of NYT api and returns dictionary with source counts
    '''
    source_count = []
    for item in articles['response']['facets']['source']['terms']:
        source = {}
        count = int(item['count'])
        pub = item['term']
        source[pub] = count
        source_count.append(source)
    return(source_count)

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980') and a query (e.g.'Amnesty International') 
    and it will return a list of parsed articles (in dictionaries) for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query,
                      fq = {'source':['Reuters','AP', 'The New York Times']}, 
                      facet_field='source',
                      begin_date = date + '0101',
                      end_date = date + '1231',
                      facet_filter='true',
                      sort='oldest',
                      page = str(i))
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
Amnesty_1 = get_articles('1980','Amnesty International')

# %%
Amnesty_all = []
for i in range(1980,2014):
    Amnesty_year = get_articles(str(i),'Amnesty International')
    print i
    Amnesty_all = Amnesty_all + Amnesty_year
# Out:
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013

# %%
for i in range(4000,56000):
    if Amnesty_all[i]['abstract'] is not None:
        try: 
            Amnesty_all[i]['abstract'] = Amnesty_all[i]['abstract'].encode("utf8")
        except:
            print i
# Out:
# 4376
# 5057
# 5228
# 5245
# 5274
# 5302
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-185-4f14b6368d14> in <module>()
#       1 for i in range(4000,56000):
# ----> 2     if Amnesty_all[i]['abstract'] is not None:
#       3         try:
#       4             Amnesty_all[i]['abstract'] = Amnesty_all[i]['abstract'].encode("utf8")
#       5         except:
#
# IndexError: list index out of range

# %%
Amnesty_all[4376]['abstract'] = Amnesty_all[4376]['abstract'].encode("utf8")

# %% [markdown]
# ### Pickling

# %%
import pprint, pickle

# %%
def ld_writeDicts(filePath,dict):  
    f=open(filePath,'w')  
    newData = pickle.dumps(dict, 1)  
    f.write(newData)  
    f.close()

# %%
ld_writeDicts('Data/Python-output/Amnesty_in_nyt.pkl',Amnesty_all)

# %% [markdown]
# ### Writing CSV

# %%
import csv

# %%
keys = Amnesty_all[0].keys()
with open('amnesty-mentions.csv', 'wb') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(Amnesty_all)

# %%
articles = api.search( q = 'Obama', fq = {'headline':'Obama', 'source':['Reuters','AP', 'The New York Times']}, begin_date = 20111231, facet_field = ['source','day_of_week'], facet_filter = True )

# %%
articles
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'54cd161379881063e978c194',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By MITCH SMITH',
#      u'person': [{u'firstname': u'Mitch',
#        u'lastname': u'SMITH',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Blue Dot for Obama Prompts Red Nebraska to Revisit Electoral College Rules',
#      u'print_headline': u'Blue Dot for Obama Prompts Red Nebraska to Revisit Electoral College Rules'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Nebraska'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Presidential Election of 2008'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Electoral College'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'7',
#       u'value': u'Republican Party'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'8',
#       u'value': u'Democratic Party'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'9',
#       u'value': u'Presidential Elections (US)'}],
#     u'lead_paragraph': u'Nebraska is one of just two states, along with Maine, that do not award all their electoral voters to the statewide winner.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/02/01/us/01electoral/01electoral-thumbWide-v2.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/02/01/us/01electoral/01electoral-thumbWide-v2.jpg',
#       u'width': 190},
#      {u'height': 737,
#       u'legacy': {u'xlarge': u'images/2015/02/01/us/01electoral/01electoral-articleLarge.jpg',
#        u'xlargeheight': u'737',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/02/01/us/01electoral/01electoral-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/02/01/us/01electoral/01electoral-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/02/01/us/01electoral/01electoral-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'11',
#     u'pub_date': u'2015-02-01T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'Nebraska is one of just two states, along with Maine, that do not award all their electoral voters to the statewide winner.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/02/01/us/politics/blue-dot-for-obama-prompts-red-nebraska-to-revisit-electoral-college-rules.html',
#     u'word_count': u'1062'},
#    {u'_id': u'54ca798d79881068566a0f21',
#     u'abstract': u"Senate votes 62 to 36 on bill to force approval of Keystone XL oil pipeline; vote sets up new body's first major clash with Pres Obama, who is certain to exercise veto; increases pressure on Obama to make final decision on Keystone, which has been subject of five-year battle.",
#     u'blog': [],
#     u'byline': {u'original': u'By CORAL DAVENPORT',
#      u'person': [{u'firstname': u'Coral',
#        u'lastname': u'DAVENPORT',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Senate Approves Keystone XL Pipeline Bill, Testing Obama',
#      u'print_headline': u'Testing Obama, Senate Approves Keystone Bill'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Keystone Pipeline System'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Oil (Petroleum) and Gasoline'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'4',
#       u'value': u'Senate'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Law and Legislation'}],
#     u'lead_paragraph': u'As expected, the Senate passed the bill forcing approval of the oil pipeline from Canada to the Gulf Coast &#8212; a measure President Obama has promised to veto.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/30/us/30keystone-web/30keystone-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/us/30keystone-web/30keystone-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/30/us/30keystone-web/30keystone-web-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/us/30keystone-web/30keystone-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/30/us/30keystone-web/30keystone-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/us/30keystone-web/30keystone-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'16',
#     u'pub_date': u'2015-01-30T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'As expected, the Senate passed the bill forcing approval of the oil pipeline from Canada to the Gulf Coast &#8212; a measure President Obama has promised to veto.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/30/us/politics/keystone-xl-pipeline-bill-senate-vote.html',
#     u'word_count': u'968'},
#    {u'_id': u'54c067977988103f1e7029cb',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#      u'original': u'By THE ASSOCIATED PRESS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Michelle Obama Accompanying Obama to India',
#      u'print_headline': u'Michelle Obama Accompanying Obama to India'},
#     u'keywords': [],
#     u'lead_paragraph': u'President Barack Obama will have a little extra company with him when he arrives in India later this week: Michelle Obama.',
#     u'multimedia': [],
#     u'news_desk': u'None',
#     u'print_page': None,
#     u'pub_date': u'2015-01-21T21:56:37Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'President Barack Obama will have a little extra company with him when he arrives in India later this week: Michelle Obama.',
#     u'source': u'AP',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/aponline/2015/01/21/us/politics/ap-us-michelle-obama-india.html',
#     u'word_count': u'117'},
#    {u'_id': u'54c75d8f798810239ad254dd',
#     u'abstract': u'Pres Obama ends three-day visit to India with speech to 1,500 mostly young Indians at Siri Fort Auditorium; calls on country to do more fight human trafficking and slavery and to protect rights of women and girls; urges India to do also make more concerted effort in addressing climate change.',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By PETER BAKER and ELLEN BARRY',
#      u'person': [{u'firstname': u'Peter',
#        u'lastname': u'BAKER',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Ellen',
#        u'lastname': u'BARRY',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'As Visit Ends, Obama Presses India on Human Rights and Climate Change ',
#      u'print_headline': u'As Visit Ends, Obama Presses India on Human Rights and Climate Change'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'India'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Human Trafficking'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Global Warming'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Modi, Narendra'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Human Rights and Human Rights Violations'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'8',
#       u'value': u'Child Labor'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'9',
#       u'value': u'United States International Relations'}],
#     u'lead_paragraph': u'President Obama pressed India on Tuesday to do more to curb emissions, as he wrapped up a trip that failed to achieve a meaningful breakthrough on the issue.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/28/world/28india04/28india04-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/28/world/28india04/28india04-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/28/world/28india04/28india04-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/28/world/28india04/28india04-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/28/world/28india04/28india04-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/28/world/28india04/28india04-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'7',
#     u'pub_date': u'2015-01-28T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'President Obama pressed India on Tuesday to do more to curb emissions, as he wrapped up a trip that failed to achieve a meaningful breakthrough on the issue.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Asia Pacific',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/28/world/asia/obama-ends-visit-with-challenge-to-india-on-climate-change.html',
#     u'word_count': u'1169'},
#    {u'_id': u'54af226479881022e94b37d6',
#     u'abstract': u'Pres Obama says he will introduce plan to make community colleges tuition-free for millions of students, in attempt to respond to rising income inequality; program would be paid for by federal government and participating states, but will probably not be welcomed by Republican Congress; Obama plans to make initiative part of his budget proposal.',
#     u'blog': [],
#     u'byline': {u'contributor': u'Julie Hirschfeld Davis reported from Washington, and Tamar Lewin from New York. Peter Baker contributed reporting from Washington.',
#      u'original': u'By JULIE HIRSCHFELD DAVIS and TAMAR LEWIN',
#      u'person': [{u'firstname': u'Julie',
#        u'lastname': u'DAVIS',
#        u'middlename': u'Hirschfeld',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Tamar',
#        u'lastname': u'LEWIN',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Obama Plan Would Help Many Go to Community College Free ',
#      u'print_headline': u'Obama Plan Would Help Many Go to Community College Free'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Community Colleges'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Colleges and Universities'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Income Inequality'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Tuition'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'5',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'United States Politics and Government'}],
#     u'lead_paragraph': u'The president\u2019s initiative, which would expand educational opportunities for millions, is another attempt to address persistent income inequality.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/09/us/09OBAMA1-web/09OBAMA1-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'1',
#     u'pub_date': u'2015-01-09T00:00:00Z',
#     u'section_name': u'Education',
#     u'snippet': u'The president\u2019s initiative, which would expand educational opportunities for millions, is another attempt to address persistent income inequality.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/09/us/politics/obama-proposes-free-community-college-education-for-some-students.html',
#     u'word_count': u'848'},
#    {u'_id': u'54cc3a6e79881027ae29df87',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'contributor': u'Peter Baker reported from Washington, and Jodi Rudoren from Jerusalem.',
#      u'original': u'By PETER BAKER and JODI RUDOREN',
#      u'person': [{u'firstname': u'Peter',
#        u'lastname': u'BAKER',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Jodi',
#        u'lastname': u'RUDOREN',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'News Analysis',
#      u'kicker': u'News Analysis',
#      u'main': u'A Strained Alliance: Obama-Netanyahu Rift Grew Over Years',
#      u'print_headline': u'A Strained Alliance'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'United States International Relations'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Defense and Military Forces'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Palestinians'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Israeli Settlements'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'Republican Party'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Netanyahu, Benjamin'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'7',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'8',
#       u'value': u'Iran'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'9',
#       u'value': u'Israel'}],
#     u'lead_paragraph': u'The diplomatic break touched off by Benjamin Netanyahu&#8217;s decision to negotiate an address to Congress without first telling President Obama reflects their fundamentally different world views.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/30/world/31DIPLO/31DIPLO-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/world/31DIPLO/31DIPLO-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 375,
#       u'legacy': {u'xlarge': u'images/2015/01/30/world/31DIPLO/31DIPLO-articleLarge.jpg',
#        u'xlargeheight': u'375',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/world/31DIPLO/31DIPLO-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/30/world/31DIPLO/31DIPLO-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/30/world/31DIPLO/31DIPLO-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'1',
#     u'pub_date': u'2015-01-31T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'The diplomatic break touched off by Benjamin Netanyahu&#8217;s decision to negotiate an address to Congress without first telling President Obama reflects their fundamentally different world views.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'An Analysis; News Analysis',
#     u'web_url': u'http://www.nytimes.com/2015/01/31/world/middleeast/a-strained-alliance-obama-netanyahu-rift-grew-over-years.html',
#     u'word_count': u'1191'},
#    {u'_id': u'54cfa40f79881002ee7b49a2',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By ANAND GIRIDHARADAS',
#      u'person': [{u'firstname': u'Anand',
#        u'lastname': u'GIRIDHARADAS',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Letter From America',
#      u'kicker': u'Letter From America',
#      u'main': u'Obama Has Little to Say to the Poor',
#      u'print_headline': u'Obama Has Little to Say to the Poor'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Poverty'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'State of the Union Message (US)'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'4',
#       u'value': u'Republican Party'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'Democratic Party'}],
#     u'lead_paragraph': u'The president\'s State of the Union address focused on "middle-class economics" and the "working family," neglecting those with little financial hope.',
#     u'multimedia': [],
#     u'news_desk': u'Foreign',
#     u'print_page': u'',
#     u'pub_date': u'2015-02-03T20:40:00Z',
#     u'section_name': u'World',
#     u'snippet': u'The president\'s State of the Union address focused on "middle-class economics" and the "working family," neglecting those with little financial hope.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Americas',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/02/03/world/americas/obama-has-little-to-say-to-the-poor.html',
#     u'word_count': u'657'},
#    {u'_id': u'54cb4c6c79881068566a11d9',
#     u'abstract': u'Public figures, and politicians in particular, should communicate their clothing and hair choices before the public does it for them.',
#     u'blog': [],
#     u'byline': {u'original': u'By VANESSA FRIEDMAN',
#      u'person': [{u'firstname': u'Vanessa',
#        u'lastname': u'FRIEDMAN',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'blogpost',
#     u'headline': {u'kicker': u'On the Runway',
#      u'main': u'The Lessons of the Michelle Obama Head Scarf Hoo-Ha'},
#     u'keywords': [{u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Michelle'},
#      {u'name': u'subject', u'rank': u'1', u'value': u'Fashion and Apparel'}],
#     u'lead_paragraph': None,
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/31/fashion/31runway-A/31runway-A-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/fashion/31runway-A/31runway-A-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 361,
#       u'legacy': {u'xlarge': u'images/2015/01/31/fashion/31runway-A/31runway-A-articleLarge.jpg',
#        u'xlargeheight': u'361',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/fashion/31runway-A/31runway-A-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/31/fashion/31runway-A/31runway-A-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/fashion/31runway-A/31runway-A-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Styles',
#     u'print_page': None,
#     u'pub_date': u'2015-01-30T04:16:14Z',
#     u'section_name': u'false',
#     u'snippet': u'Public figures, and politicians in particular, should communicate their clothing and hair choices before the public does it for them.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'false',
#     u'type_of_material': u'Blog',
#     u'web_url': u'http://runway.blogs.nytimes.com/2015/01/30/the-lessons-of-the-michelle-obama-head-scarf-hoo-ha/',
#     u'word_count': u'651'},
#    {u'_id': u'54cbf30379881027ae29dea8',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'AP', u'original': u'AP', u'person': []},
#     u'document_type': u'multimedia',
#     u'headline': {u'main': u'Obama on New Medical Funding Initiative'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Medicine and Health'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'United States Politics and Government'}],
#     u'lead_paragraph': u'The president discussed a new initiative included in his budget that would fund research into precision medicine, which tailors treatment to genetic and other factors of individual patients.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/31/us/31medicine-web/31medicine-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/us/31medicine-web/31medicine-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/31/us/31medicine-web/31medicine-web-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/us/31medicine-web/31medicine-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/31/us/31medicine-web/31medicine-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/31/us/31medicine-web/31medicine-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'U.S. / Politics',
#     u'print_page': None,
#     u'pub_date': u'2015-01-30T16:08:57Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'The president discussed a new initiative included in his budget that would fund research into precision medicine, which tailors treatment to genetic and other factors of individual patients.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'Video',
#     u'web_url': u'http://www.nytimes.com/video/us/politics/100000003483034/obama-on-new-medical-funding-initiative.html',
#     u'word_count': u'28'},
#    {u'_id': u'54bea0b57988106587ea5ff9',
#     u'abstract': u'Pres Obama delivers his sixth State of the Union address, taking credit for improving economy, defending an activist federal government and defiantly challenging Republicans in Congress to support his costly domestic plans to aid middle class; faces skeptical but respectful Congress and makes no mention of major losses Democratic Party incurred in congressional midterm elections.',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By MICHAEL D. SHEAR and JULIE HIRSCHFELD DAVIS',
#      u'person': [{u'firstname': u'Michael',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'In State of the Union, Obama Sets an Ambitious Agenda',
#      u'print_headline': u'Obama Defiantly Sets an Ambitious Agenda',
#      u'sub': u'Lays Out a Broad Vision for His Last Two Years'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'State of the Union Message (US)'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'4',
#       u'value': u'United States'}],
#     u'lead_paragraph': u'President Obama defended an activist federal government and challenged Republicans to support him on education, child care and middle-class tax breaks.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/21/us/JP-OBAMA2-sub/JP-OBAMA2-sub-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'1',
#     u'pub_date': u'2015-01-21T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'President Obama defended an activist federal government and challenged Republicans to support him on education, child care and middle-class tax breaks.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/21/us/state-of-the-union-obama-ambitious-agenda-to-help-middle-class.html',
#     u'word_count': u'1429'}],
#   u'facets': {u'day_of_week': {u'terms': [{u'count': 1305,
#       u'term': u'Wednesday'},
#      {u'count': 1264, u'term': u'Thursday'},
#      {u'count': 1221, u'term': u'Friday'},
#      {u'count': 1208, u'term': u'Tuesday'},
#      {u'count': 818, u'term': u'Monday'}]},
#    u'source': {u'terms': [{u'count': 3464, u'term': u'The New York Times'},
#      {u'count': 1890, u'term': u'Reuters'},
#      {u'count': 1683, u'term': u'AP'}]}},
#   u'meta': {u'hits': 7037, u'offset': 0, u'time': 1328}},
#  u'status': u'OK'}
